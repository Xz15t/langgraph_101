# %%
from langchain_openai import ChatOpenAI

import os
from dotenv import load_dotenv

load_dotenv()
if os.environ.get("OPENAI_API_KEY"):
    print("Open AI API Key is set.")
else:
    raise ValueError("Open AI API Key is not set")
# Out:
# Open AI API Key is set.

# %%
from langchain_core.messages import HumanMessage
llm = ChatOpenAI(model = "gpt-5-mini")

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant."),
    ("human", "{input}")
])

chat_prompt.invoke({'input': 'What is the capital of France?'})
# Out:
# ChatPromptValue(messages=[SystemMessage(content='You are a helpful assistant.', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the capital of France?', additional_kwargs={}, response_metadata={})])

# %%
chain = chat_prompt | llm
chain.invoke({'input': 'What is the capital of France?'}).content
# Out:
# 'Paris. If you’d like, I can share a few quick facts about the city.'
